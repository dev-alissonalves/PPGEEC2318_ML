# %% [markdown]
# #### **Autor**: Álisson De Oliveira Alves
# #### **Site**: https://linktr.ee/devalissonalves
# #### **Disciplina**: Aprendizado de Máquina (PPGEEC2318)
# #### **Professor**: _IVANOVITCH MEDEIROS DANTAS DA SILVA_
# ________________________________________________________________
#
# ## Livro: Projetando sistemas de _Machine Learning_
#
# ### Capítulo 1: _Overview of Machine Learning Systems_
#
# #### TÓPICO 1
#
# * Contextualização da democratização do _Machine Learning_
# _____________________________________
#
# Historicamente o contexto do aprendizado de máquina surgiu em meados de 1950, fazendo referência a capacidade das máquinas aprenderem sem a necessidade explícita de serem programadas. O livro da _Chip Huyen_ logo nos primeiros parágrafos fomenta a discussão trazendo a data do anúncio da **Google** indicando que havia incorporado ao _Google Translate_ soluções de _Deep Learning_ / *Redes Neurais Artificiais Profundas* no ano de 2016. Essa mudança na solução dessa grande companhia foi responsável por uma melhoria exponencial no processo de tradução que não se tinha visto nos últimos 10 anos. Esse marco ficou na história por ter sido um dos primeiros _cases_ do sucesso da utilização em escala de soluções envolvendo _Deep Learning_.
#
# A partir do marco apresentado no tópico anterior, é evidenciado no livro a ascenção de novos interesses no aprendizado de máquina (_Machine Learning_), pois inúmeras empresas buscaram resolver problemas complexos utilizando soluções de ML. Dessa forma, ao passar dos anos, diferentes problemas nas mais diferentes áreas das vidas dos seres humanos (saúde, transporte, educação, agricultura, dentre outros) passaram a ter envolvimento do aprendizado de máquina de alguma maneira.
#
# #### TÓPICO 2
#
# * Quando utilizar o Aprendizado de Máquina
# _____________________________________
# De maneira geral a autora chama atenção indicando a necessidade de inicialmente antes de qualquer coisa, questionar a utilização de aprendizado de máquina no contexto do problema, pois, nem sempre soluções de inteligência artificial pode ser o melhor caminho. Para tanto, é descrito que abordagens utilizando ML servem para contextos que envolvem: _"Aprender padrões complexos de dados existentes e usar esses padrões para realizar previsões sobre dados não vistos"_.
#
# * GERALMENTE SISTEMAS QUE ENVOLVEM ML PRECISAM:
#     1. Capacidade de Aprender;
#     2. Deve existir padrões para aprender (**complexos**);
#     3. Que dados estejam disponíveis;
#     4. Que seja um problema preditivo;
#     5. Dados invisíveis (_não vistos_) que compartilham padrões com os dados de treinamento;
#     6. Que padrões sejam repetidos. O modelo necessita de muitas amostras para aprender;
#     7. Que o custo das previsões errôneas seja batato;
#     8. Que estejam em escala;
#     9. Que os padrões mudem;
#
# * QUANDO NÃO SE UTILIZAR ALGORITMOS DE ML:
#     1. Quando o uso for antiético;
#     2. Quando soluções mais simples resolvem o problema;
#     3. Quando não for econômico;
#
#
# #### TÓPICO 3
#
# * Casos de Uso de _Machine Learning_
# _____________________________________
#
# A autora descreve diferentes casos de uso de _Machine Learning_, dentre eles, afirmando que houve uma aumento significativo de utilização por parte de aplicativos empresariais e de consumo. Sobre exemplos comuns é citado sistemas como Amazon e Netflix que possuem em seus serviços sistemas de recomendação com base nos perfis de usuário. Esse tipo de aplicação tem como objetivo principal fazer sugestões de conteúdos, serviços e produtos que se encaixam com os interesses e necessidades de cada pessoa.
#
# Outro ponto interessante é a contextualização que autora faz acerca do _Machine Learning_ no nosso dia a dia através dos assistentes virtuais como **Alexa**, **Google Assistant** e **Siri**. Na minha opinião isso foi um marco da democratização da inteligência artificial no mundo todo, pois, qualquer pessoa com um aparelho adequado e acesso a internet pode ter acesso e utilizar alguma das assistentes e se comunicar, pedir música favorita, pedir ajuda com alguma pergunta histórica, dentre outras aplicabilidades.
#
# O aprendizado de máquina também evoluiu e é frequente em outros tipos de equipamentos como câmeras de segurança inteligente, robôs e etc.
#
#
# #### TÓPICO 4
#
# * Entendendo Sistemas de _Machine Learning_
# _____________________________________
#
# A autora inicialmente destaca as importate diferença entre o aprendizado de máquina externado dentro da academia (Universidades, Treinamentos e etc...) e o que de fato é o aprendizado de máquina em produção ou implantado. O segundo ponto é mais complexo pois exige a rigor cuidados com o pipeline de dados, implantação do sistema e monitoramento.
#
# Ademais, é mostrado um caso de uso de uma aplicação que envolve a recomendação de restaurantes aos usuários. A partir disso, é evidenciado os profissionais envolvidos na solução, são eles:
#
# 1. Engenheiros de ML;
# 2. Profissionais de vendas;
# 3. Equipe de produto;
# 4. Equipe da plataforma de ML;
# 5. Gerente
#
# A autora indica a necessidade dos Engenheiros de ML entenderem bem os requistos de todas as partes interessadas que estão envolvidas no processo de desenvolvimento pois, requisitos conflitantes podem levar a graves dificuldades no desenvolvimento do projeto e da seleção dos modelos de aprendizado de máquina.
#
#
# ### Capítulo 2: _Introduction to Machine Learning Systems Design_
#
# #### TÓPICO 1
#
# * Contextualização sobre o desenvolvimento de projetos de ML
# _____________________________________
#
# A autora menciona a necessidade prévia de entender a necessidade do problema em sua natureza. Por exemplo, se for para uma empresa a solução de ML e o roteiro de desenvolvimento devem ter como base os objetivo do negócio para só depois de compreendido a natureza do problema, converter essas informações em objetivos que envolvem a utilização e o desenvolvimento dos algoritmos e modelos de _Machine Learning_.
#
# #### TÓPICO 2
#
# * Principais requisitos para o desenvolvimento de sistemas de ML
# _____________________________________
#
# Dentro do contexto de Engenharia de Software (quando lecionei a disciplina no IFRN em 2021), afirmava em sala de aula que requisitos são os pilares principais do desenvolvimento ágil e eficiente de software. Curiosamente, a autora menciona 4 requisitos no livro que, na minha opinão, são cruciais em qualquer desenvolvimento de sistemas, seja envolvendo ML ou não. Porém, dentro do contexto de IA, não seria diferente. Nos primeiros parágrafos é definido 4 requisitos que servem para orientar o desenvolvimento dos sistemas de ML. Sendo eles: confiabilidade, escalabilidade, sustentabilidade e adaptabilidade. Outro ponto importante é que o desenvolvimento dos sistemas de ML é interativo e interminável (segundo a autora). De fato, todo sistema que funciona em produção na maior realizando uma ingestão de dados _Real Time_ ao longo do tempo precisa adaptar os algoritmos e modelos com base na variação de dados que podem está sendo introduzidos na plataforma.
#
#
# ### Capítulo 3: _Data Engineering Fundamentals_
#
# #### TÓPICO 1
#
# * Contextualização _Big Data_
# _____________________________________
#
# Dada a complexidade de sistemas de _Big Data_ e os obstáculos associados a eles, consequentemente ocasionou um crescimento acerca do ML em diferentes áreas. A rápida evolução de padrões dentro da indústria e os dados associados a diferentes empresas, de diferentes áreas, rodeadas pela criação de novos softwares, sistemas e aplicações que ficam mais complexos a cada dia, acabam criando ambientes dinâmicos e adaptativos e que muitas vezes pode ser desafiador.
#
#
# Dada a complexidade dos sistemas de Big Data e os obstáculos associados a eles, consequentemente, o crescimento do ML em diferentes áreas foi impulsionado. A rápida evolução dos padrões da indústria, juntamente com os dados associados a diferentes empresas e áreas, conduzidos pela criação de novos softwares, sistemas e aplicações cada vez mais complexos, cria ambientes dinâmicos e adaptáveis que podem ser desafiadores.
#
# #### TÓPICO 2
#
# * Diferentes formatos de Dados
# _____________________________________
#
# A autora retrata a importância da persistência dos dados, etapa crucial após a coleta dos mesmos. No entanto, as diferentes fontes de coleta de informações podem ser um desafio pela quantidade de padrões existentes.
#
# Por fim, é mencionado as três principais abordagens de modelagem de dados atualmente, sendo eles: relacionais, orientados a documentos e a grafos.
